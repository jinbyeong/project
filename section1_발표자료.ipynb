# %% [markdown]
# <a href="https://colab.research.google.com/github/jinbyeong/project/blob/main/section1_%EB%B0%9C%ED%91%9C%EC%9E%90%EB%A3%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **다음 분기에는 어떤 게임을 출시해야 할까?**

# %% [markdown]
# ## **서론**

# %% [markdown]
#
#
# ###  **시장 규모의 변화**
# 시장의 규모는 2009년을 기점으로 줄어들지만, 매출 상위 10개의 게임이 차지하는 점유율은 증가하고있다.
#
# ![연도별 시장의 규모와 출시 수 상위 10개 게임의 출고량.png](data:image/png;base64,...)

# %% [markdown]
# ## **본론**

# %% [markdown]
# ### **시대별 게임의 트렌드**
# 시대별로 선호하는 장르가 존재한다.
# ![80s.png](data:image/png;base64,...)

# %% [markdown]
# ![90s.png](data:image/png;base64,...)

# %% [markdown]
# ![00s.png](data:image/png;base64,...)

# %% [markdown]
# ![10s.png](data:image/png;base64,...)

# %% [markdown]
# ### **지역별 선호 장르**
# 지역별로 선호하는 장르가 존재함
# ![지역별 장르의 출고량.png](data:image/png;base64,...)

# %% [markdown]
# ### **지역별 시장 규모의 변화**
# 규모가 모두 줄어들고있다.
# ![지역별 시장 규모.png](data:image/png;base64,...)

# %% [markdown]
# ### **게임 장르 규모의 변화**
# 가장 큰 규모의 장르는 Action이다.
# ![연도별 장르의 출고량.png](data:image/png;base64,...)

# %% [markdown]
# ### **지속 가능한 플랫폼**
# 플랫폼은 사라질 수도 있다.
# ![연도별 플랫폼 점유율.png](data:image/png;base64,...)

# %% [markdown]
# ### **연도별 최고매출**
# 닌텐도의 성과가 돋보인다.
#
# ![연도별 최고매출.PNG](data:image/png;base64,...)

# %% [markdown]
# ### **연도별 최고 매출의 추이**
#
#
# ![연도별 최고매출의 출고량 추이.png](data:image/png;base64,...)

# %% [markdown]
# ### **최근 최고매출의 장르**
# Action과 Sports가 대부분을 차지함.
#
# ![연도별 최고매출 장르의 카운트 00년부터.png](data:image/png;base64,...)

# %% [markdown]
# ## **결론**

# %% [markdown]
# ### NA, EU 지역을 타겟으로 한 Action장르의 게임을 PS4를 통해 출시한다.
